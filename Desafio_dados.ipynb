# %% [markdown]
# <a href="https://colab.research.google.com/github/juliomaia28/Workshop_FS_23_3/blob/main/Desafio_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
var = pd.read_csv("dados.csv")

display(var)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
var.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
description = var.describe()

#Pegando só as descrições que foram pedidas
Media = description.loc['mean']
Max = description.loc['max']
Min = description.loc['min']

Resultado = pd.DataFrame({"Maximo": Max, "Media": Media , "Minimo":Min})
display(Resultado)
# Out:
#                Maximo   Media  Minimo
# math score      100.0  66.089     0.0
# reading score   100.0  69.169    17.0
# writing score   100.0  68.054    10.0

# %%
var3 = var.groupby('race/ethnicity')[['math score']].count()
var3
# Out:
#                 math score
# race/ethnicity
# group A                 89
# group B                190
# group C                319
# group D                262
# group E                140

# %%
var3.plot(kind = 'bar')
# Out:
# <Axes: xlabel='race/ethnicity'>

# %%
var2 = var.groupby('parental level of education')[['writing score']].count()
var2
# Out:
#                              writing score
# parental level of education
# associate's degree                     222
# bachelor's degree                      118
# high school                            196
# master's degree                         59
# some college                           226
# some high school                       179

# %%
var2.plot(kind = 'bar')
# Out:
# <Axes: xlabel='parental level of education'>

# %%
var4 = var.groupby('test preparation course')[['reading score']].count()
var4
# Out:
#                          reading score
# test preparation course
# completed                          358
# none                               642

# %%
var4.plot(kind = 'bar')
# Out:
# <Axes: xlabel='test preparation course'>
